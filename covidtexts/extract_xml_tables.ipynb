# %%
from lxml import etree
import pandas as pd

# %%
tree = etree.parse("/mnt/raidtmp/joppich/pubmed_pmc/pmc/vimtm/covidtexts/PMC8358877.xml")

tables = tree.findall("//table")
tables

for table in tables:
    df = pd.read_html(etree.tostring(table,method='html'))[0]
    print(df)
# Out:
#              Name                Sequence  \
# 0    SCoV‐2‐miR‐1  UUGGCUACUAACAAUCUAGUUG
# 1    SCoV‐2‐miR‐2  GAAAUACCAGUGGCUUACCGCA
# 2    SCoV‐2‐miR‐3  CGCGACGUGCUCGUACGUGGCU
# 3    SCoV‐2‐miR‐4  CGCGACGUGCUCGUACGUGGCU
# 4    SCoV‐2‐miR‐5  GGCUACUAACAAUCUAGUUGUA
# 5    SCoV‐2‐miR‐6  AAACUCAAACCCGUCCUUGAUU
# 6    SCoV‐2‐miR‐7  UCUGCCUAUACAGUUGAACUCG
# 7    SCoV‐2‐miR‐8  UUGUGGCAGAUGCUGUCAUAAA
# 8    SCoV‐2‐miR‐9  AAACAAUUGUUGAGGUUCAACC
# 9   SCoV‐2‐miR‐10  CUUAUUACAGAGCAAGGGCUGG
# 10  SCoV‐2‐miR‐11  UCUUAGCCUACUGUAAUAAGAC
# 11  SCoV‐2‐miR‐12  GUGCACUUAUCUUAGCCUACUG
# 12  SCoV‐2‐miR‐13  UGAGUUAGGUGAUGUUAGAGAA
# 13  SCoV‐2‐miR‐14  AAGCAUCUAUGCCGACUACUAU
# 14  SCoV‐2‐miR‐15  AUCCUACUGACCAGUCUUCUUA
# 15  SCoV‐2‐miR‐16  UUGAUAGUGUUACAGUGAAGAA
# 16  SCoV‐2‐miR‐17     ACUUUGAUAAAGCUGGUCA
# 17  SCoV‐2‐miR‐18  UGUAUCUAAAGUUGCGUAGUGA
# 18  SCoV‐2‐miR‐19  CCCUAAUUAUGAAGAUUUACUC
# 19  SCoV‐2‐miR‐20  UUGUUACAUGCACCAUAUGGAA
#
#                            Target genes         Name.1  \
# 0                          GGCX, PRRC2B  SCoV‐2‐miR‐21
# 1                   FBN2, ZNF503, RAB2A  SCoV‐2‐miR‐22
# 2                                     _  SCoV‐2‐miR‐23
# 3                                     _  SCoV‐2‐miR‐24
# 4                                 ITGB1  SCoV‐2‐miR‐25
# 5                                 PTBP2  SCoV‐2‐miR‐26
# 6                    HYOU1, EDEM3, PLAT  SCoV‐2‐miR‐27
# 7                      SEPSECS, PRKAR2B  SCoV‐2‐miR‐28
# 8   RALA, RAE1, ZC3H7A, STOML2, PRKAR2B  SCoV‐2‐miR‐29
# 9                                     _  SCoV‐2‐miR‐30
# 10                               MYCBP2  SCoV‐2‐miR‐31
# 11                                    _  SCoV‐2‐miR‐32
# 12                                    _  SCoV‐2‐miR‐33
# 13                                    _  SCoV‐2‐miR‐34
# 14                                    _  SCoV‐2‐miR‐35
# 15                                    _  SCoV‐2‐miR‐36
# 16                                    _  SCoV‐2‐miR‐37
# 17                                    _  SCoV‐2‐miR‐38
# 18                                    _  SCoV‐2‐miR‐39
# 19                                    _            NaN
#
#                 Sequence.1           Target genes.1
# 0   UUGGGUAGUGCUUUAUUAGAAG            ARL6IP6, TBCA
# 1   AAGCUAAAAGACUGUGUUAUGU  ATE1, RAB10, RDX, MARK2
# 2   GGUACAACAUUUACUUAUGCAU                    MARK1
# 3   UCGUGUUGUCUGUACUGCCGUU                        _
# 4   CAGGGCUUUAACUGCAGAGUCA             MARK1, TMED5
# 5   UCACAUGUUGACACUGACUUAA                      NaN
# 6   AGUCAUCGUCAACAACCUAGAC              DDX21, ALG5
# 7   UGAAAUGGUCAUGUGUGGCGGU                        _
# 8   UGCUCGCAUAGUGUAUACAGCU                        _
# 9   GCUUAAAGCACAUAAAGACAAA                     GNG5
# 10  UGCACAUGUAGCUAGUUGUGAU                     TBCA
# 11  UGAUCUUUAUAAGCUCAUGGGA     HS2ST1, SBNO1, SPART
# 12  UCAACUGAAAUCUAUCAGGCCG                        _
# 13  CGGCGGGCACGUAGUGUAGCUA                    RAB7A
# 14  CUACACUAUGUCACUUGGUGCA                        _
# 15     UUAUGCUUUGCUGUAUGAC                        _
# 16  CGCAGCGUGUAGCAGGUGACUC                        _
# 17           GAAAUACCAGUGG                        _
# 18          CAUAAUUUCUUGGU                        _
# 19                     NaN                      NaN
#    Gene name                                       Protein name  \
# 0       GGCX              Vitamin K‐dependent gamma‐carboxylase
# 1     PRRC2B                                     Protein PRRC2B
# 2       FBN2                                        Fibrillin‐2
# 3     ZNF503                            Zinc finger protein 503
# 4      RAB2A                         Ras‐related protein Rab‐2A
# 5      ITGB1                                    Integrin beta‐1
# 6      PTBP2             Polypyrimidine tract‐binding protein 2
# 7      HYOU1                     Hypoxia up‐regulated protein 1
# 8      EDEM3  ER degradation‐enhancing alpha‐mannosidase‐lik...
# 9       PLAT                  Tissue‐type plasminogen activator
# 10   SEPSECS     O‐phosphoseryl‐tRNA (Sec) selenium transferase
# 11   PRKAR2B  cAMP‐dependent protein kinase type II‐beta reg...
# 12      RALA                          Ras‐related protein Ral‐A
# 13      RAE1                                 mRNA export factor
# 14    ZC3H7A      Zinc finger CCCH domain‐containing protein 7A
# 15    STOML2             Stomatin‐like protein 2, mitochondrial
# 16    MYCBP2                 E3 ubiquitin‐protein ligase MYCBP2
# 17   ARL6IP6  ADP‐ribosylation factor‐like protein 6‐interac...
# 18      TBCA                       Tubulin‐specific chaperone A
# 19      ATE1                Arginyl‐tRNA‐‐protein transferase 1
# 20     RAB10                         Ras‐related protein Rab‐10
# 21       RDX                                            Radixin
# 22     MARK2              Serine/threonine‐protein kinase MARK2
# 23     MARK1              Serine/threonine‐protein kinase MARK1
# 24     TMED5    Transmembrane emp24 domain‐containing protein 5
# 25     DDX21                           Nucleolar RNA helicase 2
# 26      ALG5        Dolichyl‐phosphate beta‐glucosyltransferase
# 27      GNG5  Guanine nucleotide‐binding protein G(I)/G(S)/G...
# 28    HS2ST1            Heparan sulphate 2‐O‐sulfotransferase 1
# 29     SBNO1                 Protein strawberry notch homolog 1
# 30     SPART                                            Spartin
# 31     RAB7A                         Ras‐related protein Rab‐7a
#
#           Uniport number
# 0    P38435 (VKGC_HUMAN)
# 1   Q5JSZ5 (PRC2B_HUMAN)
# 2    P35556 (FBN2_HUMAN)
# 3   Q96F45 (ZN503_HUMAN)
# 4   P61019 (RAB2A_HUMAN)
# 5    P05556 (ITB1_HUMAN)
# 6   Q9UKA9 (PTBP2_HUMAN)
# 7   Q9Y4L1 (HYOU1_HUMAN)
# 8   Q9BZQ6 (EDEM3_HUMAN)
# 9     P00750 (TPA_HUMAN)
# 10   Q9HD40 (SPCS_HUMAN)
# 11   P31323 (KAP3_HUMAN)
# 12   P11233 (RALA_HUMAN)
# 13  P78406 (RAE1L_HUMAN)
# 14  Q8IWR0 (Z3H7A_HUMAN)
# 15  Q9UJZ1 (STML2_HUMAN)
# 16  O75592 (MYCB2_HUMAN)
# 17  Q8N6S5 (AR6P6_HUMAN)
# 18   O75347 (TBCA_HUMAN)
# 19   O95260 (ATE1_HUMAN)
# 20  P61026 (RAB10_HUMAN)
# 21   P35241 (RADI_HUMAN)
# 22  Q7KZI7 (MARK2_HUMAN)
# 23  Q9P0L2 (MARK1_HUMAN)
# 24  Q9Y3A6 (TMED5_HUMAN)
# 25  Q9NR30 (DDX21_HUMAN)
# 26   Q9Y673 (ALG5_HUMAN)
# 27   P63218 (GBG5_HUMAN)
# 28  Q7LGA3 (HS2ST_HUMAN)
# 29  A3KN83 (SBNO1_HUMAN)
# 30  Q8N0X7 (SPART_HUMAN)
# 31  P51149 (RAB7A_HUMAN)
#    Unnamed: 0  Motif Logo  Width  E. value Best match in JASPAR and PLACE  \
# 0     Motif 1         NaN     50  4.37e‐04          ZN121_HUMAN.H11MO.0.C
# 1     Motif 1         NaN     50  3.87e‐02           PAX5_HUMAN.H11MO.0.A
# 2     Motif 2         NaN     50         ‐                              ‐
# 3     Motif 3         NaN     50         ‐                              ‐
# 4     Motif 4         NaN     50  2.99e‐05           PAX5_HUMAN.H11MO.0.A
# 5     Motif 4         NaN     50  3.14e‐04          ZN121_HUMAN.H11MO.0.C
# 6     Motif 5         NaN     50         ‐                              ‐
# 7     Motif 6         NaN     41  1.94e‐08            SP2_HUMAN.H11MO.0.A
# 8     Motif 6         NaN     41  1.04e‐07          PATZ1_HUMAN.H11MO.0.C
# 9     Motif 7         NaN     29  1.94e‐02           SPIB_HUMAN.H11MO.0.A
# 10    Motif 7         NaN     29  1.01e‐02          PRDM6_HUMAN.H11MO.0.C
# 11    Motif 8         NaN     15  2.10e‐04          VEZF1_HUMAN.H11MO.0.C
# 12    Motif 8         NaN     15  1.28e‐03          ZBT17_HUMAN.H11MO.0.A
# 13    Motif 9         NaN     42  1.26e‐02          Z354A_HUMAN.H11MO.0.C
# 14   Motif 10         NaN     41  1.70e‐02          PRDM6_HUMAN.H11MO.0.C
#
#                Significant GO term identified by GOMO  \
# 0   BP Sensory perception of smell BP DNA damage c...
# 1   BP Regulation of B cell receptor signalling pa...
# 2   BP Nuclear mRNA splicing, via spliceosome BP T...
# 3   BP Positive regulation of transcription from R...
# 4   BP Sensory perception of smell BP RNA splicing...
# 5   BP Sensory perception of smell BP RNA splicing...
# 6                           BP Chromatin modification
# 7   BP Negative regulation of signal transduction ...
# 8   BP Negative regulation of signal transduction ...
# 9   BP Sensory perception of smell BP G protein–co...
# 10  BP Sensory perception of smell BP G protein–co...
# 11  BP Interior/posterior pattern formation BP Neg...
# 12  BP Interior/posterior pattern formation BP Neg...
# 13  BP Sensory perception of smell BP G protein–co...
# 14  BP sensory perception of smell BP G protein–co...
#
#    Significant Biological Process term identified by UniProtKB Database
# 0   Sensory perception of smell DNA damage checkpo...
# 1   Regulating B cell receptor signalling pathway ...
# 2                                                   _
# 3                                                   _
# 4   Regulation of B cell receptor signalling pathw...
# 5   Sensory perception of smell DNA damage checkpo...
# 6                                                   _
# 7                                     Immune response
# 8                              T cell differentiation
# 9                                Cell differentiation
# 10  Regulation of gene expression Negative regulat...
# 11  Cellular defence response Endothelial cell dev...
# 12  IRE1‐mediated unfolded protein response Positi...
# 13         Response to folic acid Response to hypoxia
# 14  Regulation of gene expression Negative regulat...

# %%
# Out:
# [<Element table at 0x7fb3c6ee3588>,
#  <Element table at 0x7fb3c178ed48>,
#  <Element table at 0x7fb3c1732d08>]

# %%
# Out:
#        MatureBayes results                                            \
#                       Name  5′ stem                          3′ stem
#                       Name Position                Sequence Position
# 0    SARS-CoV-2-pre-miR-R6    15–36  AAGAGUAGACUAUAUAUCGUAA    54–75
# 1    SARS-CoV-2-pre-miR-R5    34–55  AGAUGAAACAUCUGUUGUCACU    44–65
# 2    SARS-CoV-2-pre-miR-R4    32–53  AUCAACAAUUUUAUUGUAGAUG    54–75
# 3    SARS-CoV-2-pre-miR-R3    15–36  CAUUUGAGUUAUAGUAGGGAUG    58–79
# 4    SARS-CoV-2-pre-miR-R2    24–45  UUCUUAAAAGAGGGUGUGUAGU    61–82
# 5    SARS-CoV-2-pre-miR-R1    23–44  CACUUUUCUCAAAGCUUUCGCU    48–69
# 6   SARS-CoV-2-pre-miR-D14    46–67  AUAGUGUUUAUAACACUUUGCU   81–102
# 7   SARS-CoV-2-pre-miR-D13    32–53  ACUGUUGCUACAUCACGAACGC    72–93
# 8   SARS-CoV-2-pre-miR-D12    35–56  UGAUCCUUCGUGGACAUCUUCG    52–73
# 9   SARS-CoV-2-pre-miR-D11    15–36  UUGGAGGUUCCGUGGCUAUAAA    61–82
# 10  SARS-CoV-2-pre-miR-D10     3–24  UUCAUAACAGAUGCGCAAACAG    37–58
# 11   SARS-CoV-2-pre-miR-D9     7–28  UAUGUACCACUAAAGUCUGCUA    42–63
# 12   SARS-CoV-2-pre-miR-D8    12–33  AUAAAGUUUAUUAUGGUAAUGC    44–65
# 13   SARS-CoV-2-pre-miR-D7    43–64  AUACUAGUUUGUCUGGUUUUAA    75–96
# 14   SARS-CoV-2-pre-miR-D6    33–54  AUGUAUCUAAAGUUGCGUAGUG   99–120
# 15   SARS-CoV-2-pre-miR-D5    26–47  AGCAGCUCGGCAAGGGUUUGUU    42–63
# 16   SARS-CoV-2-pre-miR-D4     5–26  ACCUAUACUGUUACUAGAUCAG    39–60
# 17   SARS-CoV-2-pre-miR-D3    37–58  CUGCCUAUACAGUUGAACUCGG    69–90
# 18   SARS-CoV-2-pre-miR-D2    27–48  ACUCAAACCCGUCCUUGAUUGG    64–85
# 19   SARS-CoV-2-pre-miR-D1     7–28  AGAUGGAAUUUCACAGUAUUCA    41–62
#
#
#
#                   Sequence
# 0   UUUAUAUAGCCCAUCUGCCUUG
# 1   UCUGUUGUCACUUACUGUACAA
# 2   AAGAAGGUAACAUGUUCAACAC
# 3   AAAAGUGCAUCUUGAUCCUCAU
# 4   CCACCACAUCACCAUUUAAGUC
# 5   AUUUCAGUAGUGCCACCAGCCU
# 6   AAAGACAGAAUGAUUGAACUUU
# 7   GAGCUUCGCAGCGUGUAGCAGG
# 8   CUUCGUAUUGCUGGACACCAUC
# 9   UGAUCUUUAUAAGCUCAUGGGA
# 10  GUGUGUGUUCUGUUAUUGAUUU
# 11  UUGCAAUUUAGGUGGUGCUGUC
# 12  GCCAUUUCCAUGUGGGCUCUUA
# 13  UGUGUUAUGUAUGCAUCAGCUG
# 14  UAUAAUAAGUACAAGUAUUUUA
# 15  UUUGUUGAUUCAGAUGUAGAAA
# 16  GAUGUUGGUGAUAGUGCGGAAG
# 17  AAUGAGUUCGCCUGUGUUGUGG
# 18  AAGGAAGGUGUAGAGUUUCUUA
# 19  GAUGCUAUGAUGUUCACAUCUG

# %%
[x for x in df.columns]
# Out:
# [('MatureBayes results', 'Name', 'Name'),
#  ('MatureBayes results', '5′ stem', 'Position'),
#  ('MatureBayes results', '5′ stem', 'Sequence'),
#  ('MatureBayes results', '3′ stem', 'Position'),
#  ('MatureBayes results', '3′ stem', 'Sequence')]

# %%
isinstance(df.columns, pd.MultiIndex)
# Out:
# True

# %%
print("Fixing Columns")
ndf = df.copy()
ndf.columns = list(ndf.columns.get_level_values(len(ndf.columns.levels)-1))
print(ndf.columns)
# Out:
# Fixing Columns
# Index(['Name', 'Position', 'Sequence', 'Position', 'Sequence'], dtype='object')

# %%
ndf.T.reset_index().T.reset_index(drop=True)
# Out:
#                          0         1                       2         3  \
# 0                     Name  Position                Sequence  Position
# 1    SARS-CoV-2-pre-miR-R6     15–36  AAGAGUAGACUAUAUAUCGUAA     54–75
# 2    SARS-CoV-2-pre-miR-R5     34–55  AGAUGAAACAUCUGUUGUCACU     44–65
# 3    SARS-CoV-2-pre-miR-R4     32–53  AUCAACAAUUUUAUUGUAGAUG     54–75
# 4    SARS-CoV-2-pre-miR-R3     15–36  CAUUUGAGUUAUAGUAGGGAUG     58–79
# 5    SARS-CoV-2-pre-miR-R2     24–45  UUCUUAAAAGAGGGUGUGUAGU     61–82
# 6    SARS-CoV-2-pre-miR-R1     23–44  CACUUUUCUCAAAGCUUUCGCU     48–69
# 7   SARS-CoV-2-pre-miR-D14     46–67  AUAGUGUUUAUAACACUUUGCU    81–102
# 8   SARS-CoV-2-pre-miR-D13     32–53  ACUGUUGCUACAUCACGAACGC     72–93
# 9   SARS-CoV-2-pre-miR-D12     35–56  UGAUCCUUCGUGGACAUCUUCG     52–73
# 10  SARS-CoV-2-pre-miR-D11     15–36  UUGGAGGUUCCGUGGCUAUAAA     61–82
# 11  SARS-CoV-2-pre-miR-D10      3–24  UUCAUAACAGAUGCGCAAACAG     37–58
# 12   SARS-CoV-2-pre-miR-D9      7–28  UAUGUACCACUAAAGUCUGCUA     42–63
# 13   SARS-CoV-2-pre-miR-D8     12–33  AUAAAGUUUAUUAUGGUAAUGC     44–65
# 14   SARS-CoV-2-pre-miR-D7     43–64  AUACUAGUUUGUCUGGUUUUAA     75–96
# 15   SARS-CoV-2-pre-miR-D6     33–54  AUGUAUCUAAAGUUGCGUAGUG    99–120
# 16   SARS-CoV-2-pre-miR-D5     26–47  AGCAGCUCGGCAAGGGUUUGUU     42–63
# 17   SARS-CoV-2-pre-miR-D4      5–26  ACCUAUACUGUUACUAGAUCAG     39–60
# 18   SARS-CoV-2-pre-miR-D3     37–58  CUGCCUAUACAGUUGAACUCGG     69–90
# 19   SARS-CoV-2-pre-miR-D2     27–48  ACUCAAACCCGUCCUUGAUUGG     64–85
# 20   SARS-CoV-2-pre-miR-D1      7–28  AGAUGGAAUUUCACAGUAUUCA     41–62
#
#                          4
# 0                 Sequence
# 1   UUUAUAUAGCCCAUCUGCCUUG
# 2   UCUGUUGUCACUUACUGUACAA
# 3   AAGAAGGUAACAUGUUCAACAC
# 4   AAAAGUGCAUCUUGAUCCUCAU
# 5   CCACCACAUCACCAUUUAAGUC
# 6   AUUUCAGUAGUGCCACCAGCCU
# 7   AAAGACAGAAUGAUUGAACUUU
# 8   GAGCUUCGCAGCGUGUAGCAGG
# 9   CUUCGUAUUGCUGGACACCAUC
# 10  UGAUCUUUAUAAGCUCAUGGGA
# 11  GUGUGUGUUCUGUUAUUGAUUU
# 12  UUGCAAUUUAGGUGGUGCUGUC
# 13  GCCAUUUCCAUGUGGGCUCUUA
# 14  UGUGUUAUGUAUGCAUCAGCUG
# 15  UAUAAUAAGUACAAGUAUUUUA
# 16  UUUGUUGAUUCAGAUGUAGAAA
# 17  GAUGUUGGUGAUAGUGCGGAAG
# 18  AAUGAGUUCGCCUGUGUUGUGG
# 19  AAGGAAGGUGUAGAGUUUCUUA
# 20  GAUGCUAUGAUGUUCACAUCUG
